# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import pandas as pd
df = pd.read_csv('/kaggle/input/jobs-and-salaries-in-data-field-2024/jobs_in_data_2024.csv')
df.head(10)
# Out:
#    work_year experience_level employment_type               job_title  salary  \
# 0       2024      Entry-level       Freelance  Applied Data Scientist   30000
# 1       2024        Executive       Full-time   Business Intelligence  230000
# 2       2024        Executive       Full-time   Business Intelligence  176900
# 3       2024           Senior       Full-time          Data Architect  171210
# 4       2024           Senior       Full-time          Data Architect   92190
# 5       2024        Mid-level       Full-time            Data Science   46203
# 6       2024        Mid-level       Full-time            Data Science   38280
# 7       2024      Entry-level       Full-time         Insight Analyst   50000
# 8       2024      Entry-level       Full-time         Insight Analyst   40000
# 9       2024           Senior       Full-time           Data Engineer  276000
#
#   salary_currency  salary_in_usd employee_residence work_setting  \
# 0             USD          30000     United Kingdom       Remote
# 1             USD         230000      United States    In-person
# 2             USD         176900      United States    In-person
# 3             USD         171210             Canada    In-person
# 4             USD          92190             Canada    In-person
# 5             GBP          57753     United Kingdom    In-person
# 6             GBP          47850     United Kingdom    In-person
# 7             USD          50000      United States       Remote
# 8             USD          40000      United States       Remote
# 9             USD         276000      United States    In-person
#
#   company_location company_size                    job_category
# 0   United Kingdom            M       Data Science and Research
# 1    United States            M            BI and Visualization
# 2    United States            M            BI and Visualization
# 3           Canada            M  Data Architecture and Modeling
# 4           Canada            M  Data Architecture and Modeling
# 5   United Kingdom            M       Data Science and Research
# 6   United Kingdom            M       Data Science and Research
# 7    United States            M                   Data Analysis
# 8    United States            M                   Data Analysis
# 9    United States            M                Data Engineering

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'work_setting', 'company_location', 'company_size', 'job_category'],
#       dtype='object')

# %%
df.shape
# Out:
# (14199, 12)

# %%
#Checking for the missing values
print("=== Missing Values per Column ===")
print(df.isnull().sum())
# Out:
# === Missing Values per Column ===
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# work_setting          0
# company_location      0
# company_size          0
# job_category          0
# dtype: int64

# %%
# Checkinf the data types
print("\n=== Data Types of Each Column ===")
print(df.dtypes)
# Out:
# === Data Types of Each Column ===
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# work_setting          object
# company_location      object
# company_size          object
# job_category          object
# dtype: object

# %%
# Checking for duplicate rows in the data
print("\n=== Number of Duplicate Rows ===")
print(df.duplicated().sum())
# Out:
# === Number of Duplicate Rows ===
# 5493

# %%
##removes the duplicates and resets the index.
df = df.drop_duplicates(keep='first').reset_index(drop=True)
df.shape
# Out:
# (8706, 12)

# %%
#Checking for outliers (using IQR method for numeric columns only)
print("\n=== Outlier Detection (IQR Method) ===")
numeric_cols = df.select_dtypes(include=['int64','float64']).columns
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"{col}: {len(outliers)} potential outliers")
# Out:
# === Outlier Detection (IQR Method) ===
# work_year: 266 potential outliers
# salary: 132 potential outliers
# salary_in_usd: 137 potential outliers

# %%
## To check the top 10 highest salary outliers.
Q1 = df['salary_in_usd'].quantile(0.25)
Q3 = df['salary_in_usd'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outlier_rows = df[(df['salary_in_usd'] < lower_bound) | (df['salary_in_usd'] > upper_bound)]
outlier_rows.sort_values(by='salary_in_usd', ascending=False).head(10)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 8510       2020        Mid-level       Full-time        Research Scientist
# 2484       2024           Senior       Full-time         Research Engineer
# 1569       2024        Executive       Full-time  Head of Machine Learning
# 2243       2024        Mid-level       Full-time        Research Scientist
# 2418       2024           Senior       Full-time         Research Engineer
# 1560       2024           Senior       Full-time        Research Scientist
# 1185       2024        Mid-level       Full-time               ML Engineer
# 108        2024        Mid-level       Full-time         Research Engineer
# 1588       2024        Executive       Full-time  Head of Machine Learning
# 7545       2022        Mid-level       Full-time              Data Analyst
#
#       salary salary_currency  salary_in_usd employee_residence work_setting  \
# 8510  450000             USD         450000      United States    In-person
# 2484  450000             USD         450000      United States    In-person
# 1569  448000             USD         448000      United States       Remote
# 2243  440000             USD         440000      United States    In-person
# 2418  440000             USD         440000      United States    In-person
# 1560  440000             USD         440000      United States    In-person
# 1185  440000             USD         440000      United States    In-person
# 108   440000             USD         440000      United States    In-person
# 1588  438000             USD         438000      United States    In-person
# 7545  350000             GBP         430967     United Kingdom    In-person
#
#      company_location company_size               job_category
# 8510    United States            M  Data Science and Research
# 2484    United States            M  Data Science and Research
# 1569    United States            M    Machine Learning and AI
# 2243    United States            M  Data Science and Research
# 2418    United States            M  Data Science and Research
# 1560    United States            M  Data Science and Research
# 1185    United States            M    Machine Learning and AI
# 108     United States            M  Data Science and Research
# 1588    United States            M    Machine Learning and AI
# 7545   United Kingdom            M              Data Analysis

# %%
import os
import pandas as pd
df_1 = pd.read_csv('/kaggle/input/enterprise-genai-adoption-and-workforce-impact-data/Enterprise_GenAI_Adoption_Impact.csv')
df_1.head(10)
# Out:
#                               Company Name        Industry       Country  \
# 0                      Davis LLC Pvt. Ltd.      Healthcare           USA
# 1  Roberts, Holland and Bradshaw Pvt. Ltd.         Telecom  South Africa
# 2                      Roman Inc Pvt. Ltd.     Advertising         India
# 3              Nguyen-Strickland Pvt. Ltd.      Technology            UK
# 4                    Jackson PLC Pvt. Ltd.     Hospitality            UK
# 5                     Forbes Ltd Pvt. Ltd.   Entertainment   Switzerland
# 6     Barker, Williams and Lynch Pvt. Ltd.         Telecom  South Africa
# 7      Wheeler, Warner and Brown Pvt. Ltd.     Advertising           USA
# 8     Ramirez, Wells and Cochran Pvt. Ltd.      Technology   South Korea
# 9                     Morris Inc Pvt. Ltd.  Legal Services   Switzerland
#
#   GenAI Tool  Adoption Year  Number of Employees Impacted  New Roles Created  \
# 0    Mixtral           2022                          5277                  8
# 1     Claude           2023                         18762                 17
# 2     Gemini           2023                         11307                 17
# 3       Groq           2023                         18834                 12
# 4      LLaMA           2024                          8364                 22
# 5     Gemini           2022                         16082                 16
# 6    Mixtral           2022                           994                 11
# 7       Groq           2022                         16429                 16
# 8     Gemini           2022                         12952                  7
# 9    ChatGPT           2022                          4144                 24
#
#    Training Hours Provided  Productivity Change (%)  \
# 0                      657                     25.2
# 1                    23021                     27.5
# 2                     4680                     11.5
# 3                     1750                      7.0
# 4                     3925                      2.5
# 5                    11485                     19.9
# 6                     2593                      6.6
# 7                    11692                     20.4
# 8                    22484                     29.5
# 9                    20689                     33.3
#
#                                   Employee Sentiment
# 0  Productivity increased, but there's anxiety ab...
# 1  We now finish tasks faster, but some older emp...
# 2  Productivity increased, but there's anxiety ab...
# 3  AI helped me reduce repetitive tasks, but lear...
# 4  Job roles have shifted a lot, which is both go...
# 5  New roles are exciting; transition was smoothe...
# 6  Job roles have shifted a lot, which is both go...
# 7  Collaboration improved; documentation and meet...
# 8  There's concern that AI will replace some of u...
# 9  I love using AI—it makes my job easier and mor...

# %%
df_1.columns
# Out:
# Index(['Company Name', 'Industry', 'Country', 'GenAI Tool', 'Adoption Year',
#        'Number of Employees Impacted', 'New Roles Created',
#        'Training Hours Provided', 'Productivity Change (%)',
#        'Employee Sentiment'],
#       dtype='object')

# %%
df_1.shape
# Out:
# (100000, 10)

# %%
#Checking for the missing values
print("=== Missing Values per Column ===")
print(df_1.isnull().sum())
# Out:
# === Missing Values per Column ===
# Company Name                    0
# Industry                        0
# Country                         0
# GenAI Tool                      0
# Adoption Year                   0
# Number of Employees Impacted    0
# New Roles Created               0
# Training Hours Provided         0
# Productivity Change (%)         0
# Employee Sentiment              0
# dtype: int64

# %%
# Checkinf the data types
print("\n=== Data Types of Each Column ===")
print(df_1.dtypes)
# Out:
# === Data Types of Each Column ===
# Company Name                     object
# Industry                         object
# Country                          object
# GenAI Tool                       object
# Adoption Year                     int64
# Number of Employees Impacted      int64
# New Roles Created                 int64
# Training Hours Provided           int64
# Productivity Change (%)         float64
# Employee Sentiment               object
# dtype: object

# %%
# Checking for duplicate rows in the data
print("\n=== Number of Duplicate Rows ===")
print(df_1.duplicated().sum())
# Out:
# === Number of Duplicate Rows ===
# 0

# %%
## To check the number of potential outliers
# Select numeric columns
numeric_cols = df_1.select_dtypes(include=['int64','float64']).columns

# IQR outlier detection
for col in numeric_cols:
    Q1 = df_1[col].quantile(0.25)
    Q3 = df_1[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_1[(df_1[col] < lower_bound) | (df_1[col] > upper_bound)]
    print(f"{col}: {len(outliers)} potential outliers")
# Out:
# Adoption Year: 0 potential outliers
# Number of Employees Impacted: 0 potential outliers
# New Roles Created: 0 potential outliers
# Training Hours Provided: 0 potential outliers
# Productivity Change (%): 0 potential outliers
